# %% [markdown]
# ## Reproduce example Figures in [Hierarchical Causal Models](https://arxiv.org/abs/2401.05330) (Weinstein and Blei, 2024)

# %%
from pathlib import Path

from IPython.display import SVG
from matplotlib_inline.backend_inline import set_matplotlib_formats

from y0.algorithm.identify import identify_outcomes
from y0.dsl import A, Y
from y0.examples import hierarchical as hcme
from y0.hierarchical import (
    HierarchicalCausalModel,
    QVariable,
    augment_collapsed_model,
    augment_from_mechanism,
    collapse_hcm,
    marginalize_augmented_model,
)

set_matplotlib_formats("svg")

image_dir = Path(".").parent.joinpath("images", "hierarchical")
image_dir.mkdir(exist_ok=True)


def _draw(hcm, name: str) -> SVG:
    graph = hcm.to_pygraphviz()
    graph.layout("dot")
    svg = graph.draw(format="svg:cairo").decode("utf8")
    return SVG(svg)


Qy = QVariable.parse_str("Q^Y")
Qa = QVariable.parse_str("Q^A")
Qax = QVariable.parse_str("Q^{A|X}")

# %% [markdown]
# # Figure 2

# %% [markdown]
# ## Confounder

# %% [markdown]
# Create the hierarchical causal model (HCM) in pygraphviz
#
# Figure 2 (a)

# %%
confounder_hcm = hcme.confounder_hcm

_draw(confounder_hcm, "confounder_HCM.svg")

# %% [markdown]
# Create the collapsed model as an NxMixedGraph
# (note that the paper displays latent variables but here we use semiMarkov graphs with latent variable connections represented by undirected edges)
#
# Figure 2 (c)

# %%
confounder_collapsed = collapse_hcm(confounder_hcm)
confounder_collapsed.draw()

# %% [markdown]
# Augment the collapsed model with new $Q_y$ variable and its mechanism $Q_y = m(Q_{y|a}, Q_a)$ from $\Pr(Y) = \Pr(Y | A) \Pr(A)$
#
# Figure 2 (d)

# %%
subg = confounder_hcm.get_subunit_graph()
confounder_augmented = augment_collapsed_model(confounder_collapsed, subg, "Q^Y")
confounder_augmented.draw(prog="neato")

# %%
identify_outcomes(outcomes={Qy}, treatments={Qa}, graph=confounder_augmented)
# Out:
# Sum[QVariable(Y, ['A'])](P(QVariable(Y, []) | QVariable(A, []), QVariable(Y, ['A'])) * Sum[QVariable(A, []), QVariable(Y, [])](P(QVariable(A, []), QVariable(Y, []), QVariable(Y, ['A']))))

# %% [markdown]
# ## Confounder and Interference
#
# Create the HCM in pygraphviz
#
# Figure 2 (e)

# %%
conf_and_int_hcm = hcme.get_confounder_interference_hcm()

_draw(conf_and_int_hcm, "confounder_and_interference_HCM.svg")

# %% [markdown]
# Create the collapsed model as an NxMixed Graph
#
# Figure 2 (g)

# %%
conf_and_int_collapsed = collapse_hcm(conf_and_int_hcm)
conf_and_int_collapsed.draw(prog="neato")

# %% [markdown]
# Augment the collapsed model with new variable $Q_y$ and its mechanism $Q_y = m(Q_{y|a}, Q_a)$ from $\Pr(Y) = \Pr(Y|A) \Pr(A)$
#
# Figure 2 (h)

# %%
conf_and_int_augmented = augment_collapsed_model(
    conf_and_int_collapsed, conf_and_int_hcm.get_subunit_graph(), "Q^Y"
)
conf_and_int_augmented.draw(prog="dot")

# %%
identify_outcomes(graph=conf_and_int_augmented, treatments=Qa, outcomes=Qy)
# Out:
# Sum[QVariable(Y, ['A']), Z](P(QVariable(Y, []) | QVariable(A, []), QVariable(Y, ['A']), Z) * P(Z | QVariable(A, [])) * Sum[QVariable(A, [])](P(QVariable(A, [])) * P(QVariable(Y, ['A']) | QVariable(A, []), Z)))

# %% [markdown]
# ## Instrument
#
# Create the HCM in pygraphviz
#
# Figure 2 (i)

# %%
instrument_hcm = hcme.get_instrument_hcm()

_draw(instrument_hcm, "instrument_HCM.svg")

# %% [markdown]
# Create the collapsed model as an NxMixedGraph
#
# Figure 2 (k)

# %%
instrument_collapsed = collapse_hcm(instrument_hcm)
instrument_collapsed.draw()

# %% [markdown]
# Augment the collapsed model with new variable $Q_a$ and its mechanism $Q_a = m(Q_{a|z}, Q_z)$ from $\Pr(A) = \Pr(A|Z) \Pr(Z)$
#
# Figure A2

# %%
instrument_augmented = augment_collapsed_model(
    instrument_collapsed, instrument_hcm.get_subunit_graph(), "Q^A"
)
instrument_augmented.draw()

# %%
identify_outcomes(outcomes={Y}, treatments={Qa}, graph=instrument_augmented)
# Out:
# Sum[QVariable(A, ['Z'])](P(QVariable(A, ['Z']) | QVariable(Z, [])) * P(Y | QVariable(A, []), QVariable(A, ['Z']), QVariable(Z, [])))

# %% [markdown]
# Marginalize out the $Q_z$ variable to ensure subunit positivity
#
# Figure 2 (d)

# %%
instrument_marg = marginalize_augmented_model(instrument_augmented, "Q^A", ["Q^Z"])
instrument_marg.draw(prog="neato")

# %%
identify_outcomes(
    graph=instrument_marg,
    treatments=Qa,
    outcomes=Y,
)
# Out:
# Sum[QVariable(A, ['Z'])](P(QVariable(A, ['Z'])) * P(Y | QVariable(A, []), QVariable(A, ['Z'])))

# %% [markdown]
# # Figure A3

# %% [markdown]
# (a)

# %%
HCM = HierarchicalCausalModel.from_lists(
    observed_subunits=["A", "W"],
    observed_units=["Y"],
    unobserved_units=["U"],
    edges=[("U", "A"), ("A", "Y"), ("A", "W"), ("U", "W"), ("W", "Y")],
)

_draw(HCM, "A3_a.svg")

# %% [markdown]
# (b)

# %%
col = collapse_hcm(HCM)
col.draw(prog="neato")

# %%
identify_outcomes(outcomes={Y}, treatments={Qa}, graph=col)
# Out:
# Sum[QVariable(W, ['A'])](P(Y | QVariable(A, []), QVariable(W, ['A'])) * Sum[QVariable(A, []), Y](P(QVariable(A, []), QVariable(W, ['A']), Y)))

# %% [markdown]
# (c)

# %%
HCM = HierarchicalCausalModel.from_lists(
    observed_subunits=["A", "Y", "Z"],
    unobserved_units=["U"],
    edges=[("U", "A"), ("A", "Y"), ("A", "Z"), ("Z", "Y"), ("U", "Z"), ("U", "Y")],
)

_draw(HCM, "A3_c.svg")

# %%
col = collapse_hcm(HCM)
col.draw(prog="neato")

# %% [markdown]
# (d)

# %%
aug = augment_collapsed_model(col, HCM.get_subunit_graph(), "Q^Y")
aug.draw(prog="neato")

# %%
identify_outcomes(graph=aug, treatments=Qa, outcomes=Qy)
# Out:
# Sum[QVariable(Y, ['Z', 'A']), QVariable(Z, ['A'])](P(QVariable(Y, []) | QVariable(A, []), QVariable(Y, ['Z', 'A']), QVariable(Z, ['A'])) * Sum[QVariable(A, []), QVariable(Y, [])](P(QVariable(A, []), QVariable(Y, ['Z', 'A']), QVariable(Y, []), QVariable(Z, ['A']))))

# %% [markdown]
# (e)

# %%
HCM = HierarchicalCausalModel.from_lists(
    observed_subunits=["A", "Z"],
    observed_units=["W", "Y"],
    unobserved_units=["U", "U2"],
    edges=[
        ("U", "A"),
        ("U", "Z"),
        ("A", "Z"),
        ("A", "W"),
        ("A", "Y"),
        ("W", "Y"),
        ("W", "Z"),
        ("Z", "Y"),
        ("U2", "W"),
        ("U2", "Y"),
    ],
)

_draw(HCM, "A3_e.svg")

# %% [markdown]
# (f)

# %%
col = collapse_hcm(HCM)
col.draw()

# %%
identify_outcomes(outcomes={Y}, treatments={Qa}, graph=col)
# Out:
# Sum[W, QVariable(Z, ['A'])](Sum[QVariable(A, [])](P(QVariable(A, [])) * P(QVariable(Z, ['A']) | QVariable(A, []), W)) * P(W | QVariable(A, [])) * P(Y | QVariable(A, []), W, QVariable(Z, ['A'])))

# %% [markdown]
# (g)

# %%
HCM = HierarchicalCausalModel.from_lists(
    observed_subunits=["A", "X", "Y"],
    observed_units=["Z"],
    unobserved_units=["U"],
    edges=[
        ("U", "A"),
        ("U", "X"),
        ("U", "Y"),
        ("A", "Z"),
        ("A", "Y"),
        ("Z", "Y"),
        ("X", "A"),
        ("X", "Y"),
        ("X", "Z"),
    ],
)

_draw(HCM, "A3_g.svg")

# %%
col = collapse_hcm(HCM)
col.draw(prog="neato")

# %%
aug = augment_collapsed_model(col, HCM.get_subunit_graph(), "Q^Y")
aug.draw(prog="neato")

# %%
identify_outcomes(outcomes={Qy}, treatments={Qax}, graph=aug)
# Out:
# Sum[QVariable(X, []), QVariable(Y, ['X', 'A']), Z](P(QVariable(Y, []) | QVariable(A, ['X']), QVariable(X, []), QVariable(Y, ['X', 'A']), Z) * P(Z | QVariable(A, ['X']), QVariable(X, [])) * Sum[QVariable(A, ['X'])](P(QVariable(A, ['X']) | QVariable(X, [])) * P(QVariable(X, [])) * P(QVariable(Y, ['X', 'A']) | QVariable(A, ['X']), QVariable(X, []), Z)))

# %% [markdown]
# (j)

# %%
HCM = HierarchicalCausalModel.from_lists(
    observed_subunits=["A", "X", "Z"],
    observed_units=["Y"],
    unobserved_units=["U"],
    edges=[("U", "A"), ("U", "X"), ("U", "Y"), ("Z", "A"), ("A", "Y"), ("X", "Y"), ("X", "A")],
)
_draw(HCM, "A3_j.svg")

# %%
col = collapse_hcm(HCM)
col.draw(prog="neato")

# %% [markdown]
# (k)

# %%
aug = augment_from_mechanism(
    col,
    QVariable.parse_str("Q^{A|X}"),
    [QVariable.parse_str("Q^Z"), QVariable.parse_str("Q^{A|X,Z}")],
)
aug.draw(prog="dot")

# %% [markdown]
# (l)

# %%
marg = marginalize_augmented_model(
    aug, QVariable.parse_str("Q^{A|X}"), [QVariable.parse_str("Q^Z")]
)
marg.draw()

# %%
identify_outcomes(outcomes={Y}, treatments={Qa}, graph=marg)
# Out:
# Sum[QVariable(A, ['X', 'Z']), QVariable(A, ['X']), QVariable(X, [])](P(QVariable(A, ['X']) | QVariable(A, ['X', 'Z'])) * P(QVariable(A, ['X', 'Z'])) * P(QVariable(X, []) | QVariable(A, ['X', 'Z'])) * P(Y | QVariable(A, ['X', 'Z']), QVariable(A, ['X']), QVariable(X, [])))

# %% [markdown]
# (m)

# %%
HCM = HierarchicalCausalModel.from_lists(
    observed_subunits=["A", "Y", "Z"],
    observed_units=["W"],
    unobserved_units=["U"],
    edges=[("U", "A"), ("U", "W"), ("U", "Y"), ("A", "W"), ("A", "Y"), ("W", "Y"), ("Z", "A")],
)

_draw(HCM, "A3_m.svg")

# %%
col = collapse_hcm(HCM)
col.draw(prog="neato")

# %% [markdown]
# (n) two ways

# %%
subg = HCM.get_subunit_graph()
aug1 = augment_collapsed_model(col, subg, "Q^A")
aug2 = augment_collapsed_model(aug1, subg, "Q^Y")
aug2.draw(prog="neato")

# %%
subg = HCM.get_subunit_graph()
aug1 = augment_collapsed_model(col, subg, "Q^Y")
aug2 = augment_collapsed_model(aug1, subg, "Q^A")
aug2.draw(prog="neato")

# %% [markdown]
# (o)

# %%
marg = marginalize_augmented_model(aug2, QVariable.parse_str("Q^A"), [QVariable.parse_str("Q^Z")])
marg.draw(prog="neato")

# %%
identify_outcomes(outcomes={Qy}, treatments={Qa}, graph=marg)
# Out:
# Sum[W, QVariable(Y, ['A'])](P(QVariable(Y, []) | QVariable(A, []), QVariable(A, ['Z']), W, QVariable(Y, ['A'])) * Sum[QVariable(A, ['Z'])](P(QVariable(A, ['Z'])) * P(W | QVariable(A, []), QVariable(A, ['Z'])) * P(QVariable(Y, ['A']) | QVariable(A, []), QVariable(A, ['Z']), W)))

# %% [markdown]
# (p)

# %%
HCM = HierarchicalCausalModel.from_lists(
    observed_subunits=["A", "W", "Z"],
    observed_units=["Y"],
    unobserved_units=["U"],
    edges=[
        ("U", "A"),
        ("U", "W"),
        ("U", "Y"),
        ("A", "W"),
        ("Z", "W"),
        ("W", "Y"),
    ],
)

_draw(HCM, "A3_p.svg")

# %%
col = collapse_hcm(HCM)
col.draw(prog="neato")

# %%
aug = augment_collapsed_model(col, HCM.get_subunit_graph(), "Q^W")
aug.draw(prog="neato")

# %%
marg = marginalize_augmented_model(aug, "Q^W", ["Q^Z"])
marg.draw(prog="neato")

# %%
identify_outcomes(outcomes={Y}, treatments={Qa}, graph=marg)
# Out:
# Sum[QVariable(W, ['Z', 'A']), QVariable(W, [])](P(QVariable(W, []) | QVariable(A, []), QVariable(W, ['Z', 'A'])) * Sum[QVariable(A, [])](P(QVariable(A, [])) * P(QVariable(W, ['Z', 'A']) | QVariable(A, [])) * P(Y | QVariable(A, []), QVariable(W, ['Z', 'A']), QVariable(W, []))))

# %% [markdown]
# ## Figure A4

# %% [markdown]
# (a)

# %%
HCM = HierarchicalCausalModel.from_lists(
    observed_subunits=[
        "A",
        "Y",
    ],
    observed_units=["Z"],
    unobserved_units=["U"],
    edges=[
        ("U", "A"),
        ("U", "Z"),
        ("U", "Y"),
        ("A", "Y"),
        ("Z", "Y"),
        ("A", "Z"),
    ],
)

_draw(HCM, "A4_a.svg")

# %%
col = collapse_hcm(HCM)
col.draw(prog="neato")

# %% [markdown]
# (b)

# %%
aug = augment_collapsed_model(col, HCM.get_subunit_graph(), "Q^Y")
aug.draw(prog="dot")

# %%
identify_outcomes(outcomes={Qy}, treatments={Qa}, graph=aug) is None
# Out:
# True

# %% [markdown]
# (c)

# %%
HCM = HierarchicalCausalModel.from_lists(
    observed_subunits=["A", "Z"],
    observed_units=["Y"],
    unobserved_units=["U1", "U2"],
    edges=[
        ("U1", "A"),
        ("U1", "Z"),
        ("U2", "A"),
        ("U2", "Y"),
        ("A", "Y"),
        ("Z", "A"),
    ],
)

_draw(HCM, "A4_c.svg")

# %%
col = collapse_hcm(HCM)
col.draw(prog="neato")

# %%
aug = augment_collapsed_model(col, HCM.get_subunit_graph(), "Q^A")
aug.draw(prog="neato")

# %%
marg = marginalize_augmented_model(aug, QVariable.parse_str("Q^A"), [QVariable.parse_str("Q^Z")])
marg.draw(prog="neato")

# %%
identify_outcomes(outcomes={Y}, treatments={Qa}, graph=marg) is None
# Out:
# True

# %% [markdown]
# (f)

# %%
HCM = HierarchicalCausalModel.from_lists(
    observed_subunits=["A", "Y"],
    observed_units=["W"],
    unobserved_units=["U"],
    edges=[
        ("U", "A"),
        ("U", "W"),
        ("A", "W"),
        ("A", "Y"),
        ("W", "Y"),
    ],
)

_draw(HCM, "A4_f.svg")

# %%
col = collapse_hcm(HCM)
col.draw(prog="neato")

# %%
aug = augment_collapsed_model(col, HCM.get_subunit_graph(), "Q^Y")
aug.draw(prog="dot")

# %%
identify_outcomes(outcomes={Qy}, treatments={Qa}, graph=aug) is None
# Out:
# True

# %% [markdown]
# (h)

# %%
HCM = HierarchicalCausalModel.from_lists(
    observed_subunits=["W", "Y"],
    observed_units=["A"],
    unobserved_units=["U1", "U2"],
    edges=[
        ("U1", "A"),
        ("U1", "Y"),
        ("U2", "W"),
        ("U2", "Y"),
        ("A", "W"),
        ("W", "Y"),
    ],
)
_draw(HCM, "A4_h.svg")

# %%
col = collapse_hcm(HCM)
col.draw(prog="neato")

# %%
aug = augment_collapsed_model(col, HCM.get_subunit_graph(), "Q^Y")
aug.draw(prog="dot")

# %%
identify_outcomes(outcomes={Qy}, treatments={A}, graph=aug) is None
# Out:
# True
